# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException
import pandas as pd

# %% [markdown]
# ## LINKS

# %%
State_Links = ["https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/astc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile",
              "https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile"]

# %% [markdown]
# ## 1. Andhra Pradesh State Road Transport Corporation (APSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/apsrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Andhra_link_route(path):
    LINKS_ANDHRA = []
    ROUTE_ANDHRA = []
    
    paths = driver.find_elements(By.XPATH, path)

    for i in range(1, 6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    LINKS_ANDHRA.append(href)
                text = link.text.strip()
                if text:
                    ROUTE_ANDHRA.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//div[@class="DC_117_pageTabs " and text()={i+1}]')
            actions = ActionChains(driver)
            actions.move_to_element(next_button).click().perform()

        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(LINKS_ANDHRA), list(ROUTE_ANDHRA)

LINKS_ANDHRA, ROUTE_ANDHRA = Andhra_link_route("//a[@class='route']")
# Out:
# No more pages to paginate at page 5.

# %%
df_A=pd.DataFrame({"Route_name":ROUTE_ANDHRA,"Route_link":LINKS_ANDHRA})
df_A
# Out:
#                                  Route_name  \
# 0                   Hyderabad to Vijayawada
# 1                   Vijayawada to Hyderabad
# 2                 Kakinada to Visakhapatnam
# 3    Chittoor (Andhra Pradesh) to Bangalore
# 4                     Bangalore to Tirupati
# 5                     Tirupati to Bangalore
# 6                       Kadapa to Bangalore
# 7                       Hyderabad to Ongole
# 8   Anantapur (andhra pradesh) to Bangalore
# 9                       Bangalore to Kadapa
# 10                      Ongole to Hyderabad
# 11   Bangalore to Chittoor (Andhra Pradesh)
# 12  Bangalore to Anantapur (andhra pradesh)
# 13                Visakhapatnam to Kakinada
# 14                      Kadiri to Bangalore
# 15                   Vinukonda to Hyderabad
# 16                      Bangalore to Kadiri
# 17                Hyderabad to Narasaraopet
# 18                 Madanapalli to Bangalore
# 19                Narasaraopet to Hyderabad
# 20             Rajahmundry to Visakhapatnam
# 21                       Eluru to Hyderabad
# 22                      Chennai to Tirupati
# 23                 Bangalore to Madanapalli
# 24     Guntur (Andhra Pradesh) to Hyderabad
# 25                   Rayachoti to Bangalore
# 26                     Hyderabad to Kurnool
# 27                      Tirupati to Chennai
# 28              Visakhapatnam to Vijayawada
# 29                Rajahmundry to Vijayawada
# 30     Hyderabad to Guntur (Andhra Pradesh)
# 31   Macherla (andhra pradesh) to Hyderabad
# 32                     Nandyal to Hyderabad
# 33                       Hyderabad to Eluru
# 34                   Bangalore to Rayachoti
# 35                     Kurnool to Hyderabad
# 36                   Hyderabad to Vinukonda
# 37              Vijayawada to Visakhapatnam
# 38                     Kurnool to Bangalore
# 39                 Rajahmundry to Hyderabad
# 40              Amalapuram to Visakhapatnam
# 41                    Kurnool to Vijayawada
# 42             Visakhapatnam to Rajahmundry
# 43   Hyderabad to Macherla (andhra pradesh)
# 44                     Nellore to Bangalore
# 45                   Tadipatri to Bangalore
# 46                   Kakinada to Vijayawada
# 47              Visakhapatnam to Amalapuram
# 48                  Hyderabad to Markapuram
# 49                     Hyderabad to Nandyal
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/hyderabad-to...
# 1   https://www.redbus.in/bus-tickets/vijayawada-t...
# 2   https://www.redbus.in/bus-tickets/kakinada-to-...
# 3   https://www.redbus.in/bus-tickets/chittoor-and...
# 4   https://www.redbus.in/bus-tickets/bangalore-to...
# 5   https://www.redbus.in/bus-tickets/tirupathi-to...
# 6   https://www.redbus.in/bus-tickets/kadapa-to-ba...
# 7   https://www.redbus.in/bus-tickets/hyderabad-to...
# 8   https://www.redbus.in/bus-tickets/ananthapur-t...
# 9   https://www.redbus.in/bus-tickets/bangalore-to...
# 10  https://www.redbus.in/bus-tickets/ongole-to-hy...
# 11  https://www.redbus.in/bus-tickets/bangalore-to...
# 12  https://www.redbus.in/bus-tickets/bangalore-to...
# 13  https://www.redbus.in/bus-tickets/visakhapatna...
# 14  https://www.redbus.in/bus-tickets/kadiri-to-ba...
# 15  https://www.redbus.in/bus-tickets/vinukonda-to...
# 16  https://www.redbus.in/bus-tickets/bangalore-to...
# 17  https://www.redbus.in/bus-tickets/hyderabad-to...
# 18  https://www.redbus.in/bus-tickets/madanapalli-...
# 19  https://www.redbus.in/bus-tickets/narsaraopet-...
# 20  https://www.redbus.in/bus-tickets/rajahmundry-...
# 21  https://www.redbus.in/bus-tickets/eluru-to-hyd...
# 22  https://www.redbus.in/bus-tickets/chennai-to-t...
# 23  https://www.redbus.in/bus-tickets/bangalore-to...
# 24  https://www.redbus.in/bus-tickets/guntur-to-hy...
# 25  https://www.redbus.in/bus-tickets/rayachoti-to...
# 26  https://www.redbus.in/bus-tickets/hyderabad-to...
# 27  https://www.redbus.in/bus-tickets/tirupathi-to...
# 28  https://www.redbus.in/bus-tickets/visakhapatna...
# 29  https://www.redbus.in/bus-tickets/rajahmundry-...
# 30  https://www.redbus.in/bus-tickets/hyderabad-to...
# 31  https://www.redbus.in/bus-tickets/macherla-to-...
# 32  https://www.redbus.in/bus-tickets/nandyala-to-...
# 33  https://www.redbus.in/bus-tickets/hyderabad-to...
# 34  https://www.redbus.in/bus-tickets/bangalore-to...
# 35  https://www.redbus.in/bus-tickets/kurnool-to-h...
# 36  https://www.redbus.in/bus-tickets/hyderabad-to...
# 37  https://www.redbus.in/bus-tickets/vijayawada-t...
# 38  https://www.redbus.in/bus-tickets/kurnool-to-b...
# 39  https://www.redbus.in/bus-tickets/rajahmundry-...
# 40  https://www.redbus.in/bus-tickets/amalapuram-t...
# 41  https://www.redbus.in/bus-tickets/kurnool-to-v...
# 42  https://www.redbus.in/bus-tickets/visakhapatna...
# 43  https://www.redbus.in/bus-tickets/hyderabad-to...
# 44  https://www.redbus.in/bus-tickets/nellore-to-b...
# 45  https://www.redbus.in/bus-tickets/tadipatri-to...
# 46  https://www.redbus.in/bus-tickets/kakinada-to-...
# 47  https://www.redbus.in/bus-tickets/visakhapatna...
# 48  https://www.redbus.in/bus-tickets/hyderabad-to...
# 49  https://www.redbus.in/bus-tickets/hyderabad-to...

# %%
# change dataframe to csv
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_A.csv"
df_A.to_csv(path,index=False)

# %% [markdown]
# ## 2. Kerala State Road Transport Corporation (KSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/ksrtc-kerala/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Kerala_Routes(path):
    KERALA_LINKS = []
    KERALA_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,3):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    KERALA_LINKS.append(href)
                text = link.text.strip()
                if text:
                    KERALA_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[9]/div[2]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(KERALA_LINKS) , list(KERALA_ROUTES)

KERALA_LINKS,KERALA_ROUTES = Kerala_Routes('//a[@class="route"]')

# %%
df_k = pd.DataFrame({"Route_name":KERALA_ROUTES,"Route_link":KERALA_LINKS})
df_k
# Out:
#                          Route_name  \
# 0            Bangalore to Kozhikode
# 1            Kozhikode to Ernakulam
# 2            Kozhikode to Bangalore
# 3            Ernakulam to Kozhikode
# 4               Mysore to Kozhikode
# 5               Kozhikode to Mysore
# 6             Kozhikode to Thrissur
# 7   Kozhikode to Thiruvananthapuram
# 8             Kozhikode to Kottayam
# 9             Thrissur to Kozhikode
# 10           Bangalore to Kozhikode
# 11           Kozhikode to Ernakulam
# 12           Kozhikode to Bangalore
# 13           Ernakulam to Kozhikode
# 14              Mysore to Kozhikode
# 15              Kozhikode to Mysore
# 16            Kozhikode to Thrissur
# 17  Kozhikode to Thiruvananthapuram
# 18            Kozhikode to Kottayam
# 19            Thrissur to Kozhikode
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/bangalore-to...
# 1   https://www.redbus.in/bus-tickets/kozhikode-to...
# 2   https://www.redbus.in/bus-tickets/kozhikode-to...
# 3   https://www.redbus.in/bus-tickets/ernakulam-to...
# 4   https://www.redbus.in/bus-tickets/mysore-to-ko...
# 5   https://www.redbus.in/bus-tickets/kozhikode-to...
# 6   https://www.redbus.in/bus-tickets/kozhikode-to...
# 7   https://www.redbus.in/bus-tickets/kozhikode-to...
# 8   https://www.redbus.in/bus-tickets/kozhikode-to...
# 9   https://www.redbus.in/bus-tickets/thrissur-to-...
# 10  https://www.redbus.in/bus-tickets/bangalore-to...
# 11  https://www.redbus.in/bus-tickets/kozhikode-to...
# 12  https://www.redbus.in/bus-tickets/kozhikode-to...
# 13  https://www.redbus.in/bus-tickets/ernakulam-to...
# 14  https://www.redbus.in/bus-tickets/mysore-to-ko...
# 15  https://www.redbus.in/bus-tickets/kozhikode-to...
# 16  https://www.redbus.in/bus-tickets/kozhikode-to...
# 17  https://www.redbus.in/bus-tickets/kozhikode-to...
# 18  https://www.redbus.in/bus-tickets/kozhikode-to...
# 19  https://www.redbus.in/bus-tickets/thrissur-to-...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_k.csv"
df_k.to_csv(path,index=False)

# %% [markdown]
# ## 3. Telangana State Road Transport Corporation (TSRTC)

# %%
#open the browser

driver_T=webdriver.Chrome()

#load the webpage
driver_T.get("https://www.redbus.in/online-booking/tsrtc/?utm_source=rtchometile")

time.sleep(3)

driver_T.maximize_window()

# %%
#retrive bus links and route
wait = WebDriverWait(driver_T, 20)
def Telugana_link_route(path):   
    LINKS_TELUGANA=[]
    ROUTE_TELUGANA=[]
    
    for i in range(1,4):
        paths=driver_T.find_elements(By.XPATH,path)
        # retrive the route links 
        for links in paths:
            d = links.get_attribute("href")
            LINKS_TELUGANA.append(d)
            
        # retrive names of the routes
        for route in paths:
            ROUTE_TELUGANA.append(route.text)
            
        try:
            # Wait for the pagination element to be present
            pagination = wait.until(EC.presence_of_element_located((By.XPATH, '//*[@class="DC_117_paginationTable"]')))
            next_button = pagination.find_element(By.XPATH, f'//*[@id="root"]/div/div[4]/div[8]/div[3]')
            time.sleep(3)
            next_button.click()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at step {i}")
            break
            
    return LINKS_TELUGANA,ROUTE_TELUGANA

LINKS_TELUGANA,ROUTE_TELUGANA=Telugana_link_route("//a[@class='route']")

# %%
df_T=pd.DataFrame({"Route_name":ROUTE_TELUGANA,"Route_link":LINKS_TELUGANA})
df_T
# Out:
#                                  Route_name  \
# 0                     Hyderabad to Tirupati
# 1   Hyderabad to Anantapur (andhra pradesh)
# 2                       Hyderabad to Armoor
# 3                Hyderabad to Godavarikhani
# 4       Peddapalli (Telangana) to Hyderabad
# 5                        Hyderabad to Kodad
# 6                     Hyderabad to Tirupati
# 7   Hyderabad to Anantapur (andhra pradesh)
# 8                       Hyderabad to Armoor
# 9                Hyderabad to Godavarikhani
# 10      Peddapalli (Telangana) to Hyderabad
# 11                       Hyderabad to Kodad
# 12                    Hyderabad to Tirupati
# 13  Hyderabad to Anantapur (andhra pradesh)
# 14                      Hyderabad to Armoor
# 15               Hyderabad to Godavarikhani
# 16      Peddapalli (Telangana) to Hyderabad
# 17                       Hyderabad to Kodad
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/hyderabad-to...
# 1   https://www.redbus.in/bus-tickets/hyderabad-to...
# 2   https://www.redbus.in/bus-tickets/hyderabad-to...
# 3   https://www.redbus.in/bus-tickets/hyderabad-to...
# 4   https://www.redbus.in/bus-tickets/peddapalli-t...
# 5   https://www.redbus.in/bus-tickets/hyderabad-to...
# 6   https://www.redbus.in/bus-tickets/hyderabad-to...
# 7   https://www.redbus.in/bus-tickets/hyderabad-to...
# 8   https://www.redbus.in/bus-tickets/hyderabad-to...
# 9   https://www.redbus.in/bus-tickets/hyderabad-to...
# 10  https://www.redbus.in/bus-tickets/peddapalli-t...
# 11  https://www.redbus.in/bus-tickets/hyderabad-to...
# 12  https://www.redbus.in/bus-tickets/hyderabad-to...
# 13  https://www.redbus.in/bus-tickets/hyderabad-to...
# 14  https://www.redbus.in/bus-tickets/hyderabad-to...
# 15  https://www.redbus.in/bus-tickets/hyderabad-to...
# 16  https://www.redbus.in/bus-tickets/peddapalli-t...
# 17  https://www.redbus.in/bus-tickets/hyderabad-to...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_T.csv"
df_T.to_csv(path,index=False)

# %% [markdown]
# ## 4. Goa Transport Corporation Limited (KTCL)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/ktcl/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Kadamba_Routes(path):
    KADAMBA_LINKS = []
    KADAMBA_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    KADAMBA_LINKS.append(href)
                text = link.text.strip()
                if text:
                    KADAMBA_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,"//*[@class='DC_117_paginationTable']")))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[7]/div[5]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(KADAMBA_LINKS) , list(KADAMBA_ROUTES)

KADAMBA_LINKS,KADAMBA_ROUTES = Kadamba_Routes('//a[@class="route"]')

# %%
df_G = pd.DataFrame({"Route_name":KADAMBA_ROUTES,"Route_link":KADAMBA_LINKS})
df_G
# Out:
#                    Route_name  \
# 0      Calangute (goa) to Goa
# 1      Mopa Airport to Panaji
# 2      Goa to Calangute (goa)
# 3        Belagavi to Saquelim
# 4   Calangute (goa) to Panaji
# 5      Calangute (goa) to Goa
# 6      Mopa Airport to Panaji
# 7      Goa to Calangute (goa)
# 8        Belagavi to Saquelim
# 9   Calangute (goa) to Panaji
# 10     Calangute (goa) to Goa
# 11     Mopa Airport to Panaji
# 12     Goa to Calangute (goa)
# 13       Belagavi to Saquelim
# 14  Calangute (goa) to Panaji
# 15     Calangute (goa) to Goa
# 16     Mopa Airport to Panaji
# 17     Goa to Calangute (goa)
# 18       Belagavi to Saquelim
# 19  Calangute (goa) to Panaji
# 20     Calangute (goa) to Goa
# 21     Mopa Airport to Panaji
# 22     Goa to Calangute (goa)
# 23       Belagavi to Saquelim
# 24  Calangute (goa) to Panaji
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/calangute-go...
# 1   https://www.redbus.in/bus-tickets/mopa-airport...
# 2   https://www.redbus.in/bus-tickets/goa-to-calan...
# 3   https://www.redbus.in/bus-tickets/belagavi-to-...
# 4   https://www.redbus.in/bus-tickets/calangute-go...
# 5   https://www.redbus.in/bus-tickets/calangute-go...
# 6   https://www.redbus.in/bus-tickets/mopa-airport...
# 7   https://www.redbus.in/bus-tickets/goa-to-calan...
# 8   https://www.redbus.in/bus-tickets/belagavi-to-...
# 9   https://www.redbus.in/bus-tickets/calangute-go...
# 10  https://www.redbus.in/bus-tickets/calangute-go...
# 11  https://www.redbus.in/bus-tickets/mopa-airport...
# 12  https://www.redbus.in/bus-tickets/goa-to-calan...
# 13  https://www.redbus.in/bus-tickets/belagavi-to-...
# 14  https://www.redbus.in/bus-tickets/calangute-go...
# 15  https://www.redbus.in/bus-tickets/calangute-go...
# 16  https://www.redbus.in/bus-tickets/mopa-airport...
# 17  https://www.redbus.in/bus-tickets/goa-to-calan...
# 18  https://www.redbus.in/bus-tickets/belagavi-to-...
# 19  https://www.redbus.in/bus-tickets/calangute-go...
# 20  https://www.redbus.in/bus-tickets/calangute-go...
# 21  https://www.redbus.in/bus-tickets/mopa-airport...
# 22  https://www.redbus.in/bus-tickets/goa-to-calan...
# 23  https://www.redbus.in/bus-tickets/belagavi-to-...
# 24  https://www.redbus.in/bus-tickets/calangute-go...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_G.csv"
df_G.to_csv(path,index=False)

# %% [markdown]
# ## 5. South Bengal State Transport Corporation (SBSTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/south-bengal-state-transport-corporation-sbstc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def South_Bengal_Routes(path):
    SOUTH_BENGAL_LINKS = []
    SOUTH_BENGAL_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    SOUTH_BENGAL_LINKS.append(href)
                text = link.text.strip()
                if text:
                    SOUTH_BENGAL_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[5]/div[5]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(SOUTH_BENGAL_LINKS) , list(SOUTH_BENGAL_ROUTES)

SOUTH_BENGAL_LINKS,SOUTH_BENGAL_ROUTES = South_Bengal_Routes("//a[@class='route']")

# %%
df_SB= pd.DataFrame({"Route_name":SOUTH_BENGAL_ROUTES,"Route_link":SOUTH_BENGAL_LINKS})
df_SB
# Out:
#                            Route_name  \
# 0   Kirnahar (West Bengal) to Burdwan
# 1                 Siliguri to Kolkata
# 2               Futishanko to Kolkata
# 3   Kirnahar (West Bengal) to Burdwan
# 4                 Siliguri to Kolkata
# 5               Futishanko to Kolkata
# 6   Kirnahar (West Bengal) to Burdwan
# 7                 Siliguri to Kolkata
# 8               Futishanko to Kolkata
# 9   Kirnahar (West Bengal) to Burdwan
# 10                Siliguri to Kolkata
# 11              Futishanko to Kolkata
# 12  Kirnahar (West Bengal) to Burdwan
# 13                Siliguri to Kolkata
# 14              Futishanko to Kolkata
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/kirnahar-wes...
# 1   https://www.redbus.in/bus-tickets/siliguri-to-...
# 2   https://www.redbus.in/bus-tickets/futishanko-t...
# 3   https://www.redbus.in/bus-tickets/kirnahar-wes...
# 4   https://www.redbus.in/bus-tickets/siliguri-to-...
# 5   https://www.redbus.in/bus-tickets/futishanko-t...
# 6   https://www.redbus.in/bus-tickets/kirnahar-wes...
# 7   https://www.redbus.in/bus-tickets/siliguri-to-...
# 8   https://www.redbus.in/bus-tickets/futishanko-t...
# 9   https://www.redbus.in/bus-tickets/kirnahar-wes...
# 10  https://www.redbus.in/bus-tickets/siliguri-to-...
# 11  https://www.redbus.in/bus-tickets/futishanko-t...
# 12  https://www.redbus.in/bus-tickets/kirnahar-wes...
# 13  https://www.redbus.in/bus-tickets/siliguri-to-...
# 14  https://www.redbus.in/bus-tickets/futishanko-t...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_SB.csv"
df_SB.to_csv(path,index=False)

# %% [markdown]
# ## 6. Rajasthan State Road Transport Corporation (RSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 driver = webdriver.Chrome()
#       2 driver.get("https://www.redbus.in/online-booking/rsrtc/?utm_source=rtchometile")
#       3 time.sleep(3)
#
# NameError: name 'webdriver' is not defined

# %%
wait = WebDriverWait(driver, 10)

def Rajasthan_Routes(path):
    RAJASTHAN_LINKS = []
    RAJASTHAN_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,3):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    RAJASTHAN_LINKS.append(href)
                text = link.text.strip()
                if text:
                    RAJASTHAN_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[12]/div[2]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(RAJASTHAN_LINKS) , list(RAJASTHAN_ROUTES)

RAJASTHAN_LINKS,RAJASTHAN_ROUTES = Rajasthan_Routes('//a[@class="route"]')

# %%
df_R = pd.DataFrame({"Route_name":RAJASTHAN_ROUTES,"Route_link":RAJASTHAN_LINKS})
df_R
# Out:
#                                Route_name  \
# 0                        Sikar to Bikaner
# 1           Jodhpur to Beawar (Rajasthan)
# 2             Udaipur to Pali (Rajasthan)
# 3   Jaipur (Rajasthan) to Kota(Rajasthan)
# 4              Kota(Rajasthan) to Udaipur
# 5         Jaipur (Rajasthan) to Bharatpur
# 6           Jaipur (Rajasthan) to Mathura
# 7                        Bikaner to Sikar
# 8             Pali (Rajasthan) to Udaipur
# 9           Udaipur to Jaipur (Rajasthan)
# 10                       Sikar to Bikaner
# 11          Jodhpur to Beawar (Rajasthan)
# 12            Udaipur to Pali (Rajasthan)
# 13  Jaipur (Rajasthan) to Kota(Rajasthan)
# 14             Kota(Rajasthan) to Udaipur
# 15        Jaipur (Rajasthan) to Bharatpur
# 16          Jaipur (Rajasthan) to Mathura
# 17                       Bikaner to Sikar
# 18            Pali (Rajasthan) to Udaipur
# 19          Udaipur to Jaipur (Rajasthan)
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/sikar-to-bik...
# 1   https://www.redbus.in/bus-tickets/jodhpur-to-b...
# 2   https://www.redbus.in/bus-tickets/udaipur-to-p...
# 3   https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 4   https://www.redbus.in/bus-tickets/kota-rajasth...
# 5   https://www.redbus.in/bus-tickets/jaipur-to-bh...
# 6   https://www.redbus.in/bus-tickets/jaipur-to-ma...
# 7   https://www.redbus.in/bus-tickets/bikaner-to-s...
# 8   https://www.redbus.in/bus-tickets/pali-to-udaipur
# 9   https://www.redbus.in/bus-tickets/udaipur-to-j...
# 10  https://www.redbus.in/bus-tickets/sikar-to-bik...
# 11  https://www.redbus.in/bus-tickets/jodhpur-to-b...
# 12  https://www.redbus.in/bus-tickets/udaipur-to-p...
# 13  https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 14  https://www.redbus.in/bus-tickets/kota-rajasth...
# 15  https://www.redbus.in/bus-tickets/jaipur-to-bh...
# 16  https://www.redbus.in/bus-tickets/jaipur-to-ma...
# 17  https://www.redbus.in/bus-tickets/bikaner-to-s...
# 18  https://www.redbus.in/bus-tickets/pali-to-udaipur
# 19  https://www.redbus.in/bus-tickets/udaipur-to-j...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_R.csv"
df_R.to_csv(path,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_R.csv"
# ----> 2 df_R.to_csv(path,index=False)
#
# NameError: name 'df_R' is not defined

# %% [markdown]
# ## 7. Haryana routes

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/hrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 30)

def Himachal_Routes(path):
    HIMACHAL_LINKS = []
    HIMACHAL_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,5):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    HIMACHAL_LINKS.append(href)
                text = link.text.strip()
                if text:
                    HIMACHAL_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[9]/div[4]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(HIMACHAL_LINKS) , list(HIMACHAL_ROUTES)

HIMACHAL_LINKS,HIMACHAL_ROUTES = Himachal_Routes('//a[@class="route"]')

# %%
df_H = pd.DataFrame({"Route_name":HIMACHAL_ROUTES,"Route_link":HIMACHAL_LINKS})
df_H
# Out:
#                            Route_name  \
# 0                     Kangra to Delhi
# 1                   Palampur to Delhi
# 2                   Delhi to Palampur
# 3                  Delhi to Sarkaghat
# 4                  Ghumarwin to Delhi
# 5                    Manali to Shimla
# 6   Baddi (Himachal Pradesh) to Delhi
# 7                     Kangra to Delhi
# 8                   Palampur to Delhi
# 9                   Delhi to Palampur
# 10                 Delhi to Sarkaghat
# 11                 Ghumarwin to Delhi
# 12                   Manali to Shimla
# 13  Baddi (Himachal Pradesh) to Delhi
# 14                    Kangra to Delhi
# 15                  Palampur to Delhi
# 16                  Delhi to Palampur
# 17                 Delhi to Sarkaghat
# 18                 Ghumarwin to Delhi
# 19                   Manali to Shimla
# 20  Baddi (Himachal Pradesh) to Delhi
# 21                    Kangra to Delhi
# 22                  Palampur to Delhi
# 23                  Delhi to Palampur
# 24                 Delhi to Sarkaghat
# 25                 Ghumarwin to Delhi
# 26                   Manali to Shimla
# 27  Baddi (Himachal Pradesh) to Delhi
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/kangra-to-delhi
# 1   https://www.redbus.in/bus-tickets/palampur-to-...
# 2   https://www.redbus.in/bus-tickets/delhi-to-pal...
# 3   https://www.redbus.in/bus-tickets/delhi-to-sar...
# 4   https://www.redbus.in/bus-tickets/ghumarwin-to...
# 5   https://www.redbus.in/bus-tickets/manali-to-sh...
# 6   https://www.redbus.in/bus-tickets/baddi-himach...
# 7   https://www.redbus.in/bus-tickets/kangra-to-delhi
# 8   https://www.redbus.in/bus-tickets/palampur-to-...
# 9   https://www.redbus.in/bus-tickets/delhi-to-pal...
# 10  https://www.redbus.in/bus-tickets/delhi-to-sar...
# 11  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 12  https://www.redbus.in/bus-tickets/manali-to-sh...
# 13  https://www.redbus.in/bus-tickets/baddi-himach...
# 14  https://www.redbus.in/bus-tickets/kangra-to-delhi
# 15  https://www.redbus.in/bus-tickets/palampur-to-...
# 16  https://www.redbus.in/bus-tickets/delhi-to-pal...
# 17  https://www.redbus.in/bus-tickets/delhi-to-sar...
# 18  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 19  https://www.redbus.in/bus-tickets/manali-to-sh...
# 20  https://www.redbus.in/bus-tickets/baddi-himach...
# 21  https://www.redbus.in/bus-tickets/kangra-to-delhi
# 22  https://www.redbus.in/bus-tickets/palampur-to-...
# 23  https://www.redbus.in/bus-tickets/delhi-to-pal...
# 24  https://www.redbus.in/bus-tickets/delhi-to-sar...
# 25  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 26  https://www.redbus.in/bus-tickets/manali-to-sh...
# 27  https://www.redbus.in/bus-tickets/baddi-himach...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_H.csv"
df_H.to_csv(path,index=False)

# %% [markdown]
# ## 8. Assam State Transport Corporation (ASTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/astc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Assam_Routes(path):
    ASSAM_LINKS = []
    ASSAM_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    ASSAM_LINKS.append(href)
                text = link.text.strip()
                if text:
                    ASSAM_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[9]/div[5]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(ASSAM_LINKS) , list(ASSAM_ROUTES)

ASSAM_LINKS,ASSAM_ROUTES = Assam_Routes("//a[@class='route']")

# %%
df_AS = pd.DataFrame({"Route_name":ASSAM_ROUTES,"Route_link":ASSAM_LINKS})
df_AS
# Out:
#                              Route_name  \
# 0           North Lakhimpur to Guwahati
# 1                    Tezpur to Tinsukia
# 2                  Dergaon to Dibrugarh
# 3                       Tezpur to Moran
# 4             Tezpur to North Lakhimpur
# 5     North Lakhimpur to Nagaon (Assam)
# 6   Guwahati to Tumuki (Tezpur Medical)
# 7           North Lakhimpur to Guwahati
# 8                    Tezpur to Tinsukia
# 9                  Dergaon to Dibrugarh
# 10                      Tezpur to Moran
# 11            Tezpur to North Lakhimpur
# 12    North Lakhimpur to Nagaon (Assam)
# 13  Guwahati to Tumuki (Tezpur Medical)
# 14          North Lakhimpur to Guwahati
# 15                   Tezpur to Tinsukia
# 16                 Dergaon to Dibrugarh
# 17                      Tezpur to Moran
# 18            Tezpur to North Lakhimpur
# 19    North Lakhimpur to Nagaon (Assam)
# 20  Guwahati to Tumuki (Tezpur Medical)
# 21          North Lakhimpur to Guwahati
# 22                   Tezpur to Tinsukia
# 23                 Dergaon to Dibrugarh
# 24                      Tezpur to Moran
# 25            Tezpur to North Lakhimpur
# 26    North Lakhimpur to Nagaon (Assam)
# 27  Guwahati to Tumuki (Tezpur Medical)
# 28          North Lakhimpur to Guwahati
# 29                   Tezpur to Tinsukia
# 30                 Dergaon to Dibrugarh
# 31                      Tezpur to Moran
# 32            Tezpur to North Lakhimpur
# 33    North Lakhimpur to Nagaon (Assam)
# 34  Guwahati to Tumuki (Tezpur Medical)
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/north-lakhim...
# 1   https://www.redbus.in/bus-tickets/tezpur-to-ti...
# 2   https://www.redbus.in/bus-tickets/dergaon-to-d...
# 3   https://www.redbus.in/bus-tickets/tezpur-to-moran
# 4   https://www.redbus.in/bus-tickets/tezpur-to-no...
# 5   https://www.redbus.in/bus-tickets/north-lakhim...
# 6   https://www.redbus.in/bus-tickets/guwahati-to-...
# 7   https://www.redbus.in/bus-tickets/north-lakhim...
# 8   https://www.redbus.in/bus-tickets/tezpur-to-ti...
# 9   https://www.redbus.in/bus-tickets/dergaon-to-d...
# 10  https://www.redbus.in/bus-tickets/tezpur-to-moran
# 11  https://www.redbus.in/bus-tickets/tezpur-to-no...
# 12  https://www.redbus.in/bus-tickets/north-lakhim...
# 13  https://www.redbus.in/bus-tickets/guwahati-to-...
# 14  https://www.redbus.in/bus-tickets/north-lakhim...
# 15  https://www.redbus.in/bus-tickets/tezpur-to-ti...
# 16  https://www.redbus.in/bus-tickets/dergaon-to-d...
# 17  https://www.redbus.in/bus-tickets/tezpur-to-moran
# 18  https://www.redbus.in/bus-tickets/tezpur-to-no...
# 19  https://www.redbus.in/bus-tickets/north-lakhim...
# 20  https://www.redbus.in/bus-tickets/guwahati-to-...
# 21  https://www.redbus.in/bus-tickets/north-lakhim...
# 22  https://www.redbus.in/bus-tickets/tezpur-to-ti...
# 23  https://www.redbus.in/bus-tickets/dergaon-to-d...
# 24  https://www.redbus.in/bus-tickets/tezpur-to-moran
# 25  https://www.redbus.in/bus-tickets/tezpur-to-no...
# 26  https://www.redbus.in/bus-tickets/north-lakhim...
# 27  https://www.redbus.in/bus-tickets/guwahati-to-...
# 28  https://www.redbus.in/bus-tickets/north-lakhim...
# 29  https://www.redbus.in/bus-tickets/tezpur-to-ti...
# 30  https://www.redbus.in/bus-tickets/dergaon-to-d...
# 31  https://www.redbus.in/bus-tickets/tezpur-to-moran
# 32  https://www.redbus.in/bus-tickets/tezpur-to-no...
# 33  https://www.redbus.in/bus-tickets/north-lakhim...
# 34  https://www.redbus.in/bus-tickets/guwahati-to-...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_AS.csv"
df_AS.to_csv(path,index=False)

# %% [markdown]
# ## 9. Uttar Pradesh State Road Transport Corporation (UPSRTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/uttar-pradesh-state-road-transport-corporation-upsrtc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def Uttar_Pradesh_Routes(path):
    UP_LINKS = []
    UP_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,6):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    UP_LINKS.append(href)
                text = link.text.strip()
                if text:
                    UP_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[10]/div[5]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(UP_LINKS) , list(UP_ROUTES)

UP_LINKS,UP_ROUTES = Uttar_Pradesh_Routes('//a[@class="route"]')

# %%
df_UP = pd.DataFrame({"Route_name":UP_ROUTES,"Route_link":UP_LINKS})
df_UP
# Out:
#                                          Route_name  \
# 0   Jhansi(Uttar Pradesh) to Kanpur (Uttar Pradesh)
# 1                                Mathura to Lucknow
# 2                               Varanasi to Lucknow
# 3               Lucknow to Bareilly (Uttar Pradesh)
# 4                  Bareilly (Uttar Pradesh) to Agra
# 5                                 Delhi to Haldwani
# 6              Prayagraj(Uttar Pradesh) to Azamgarh
# 7             Shahjahanpur (Uttar Pradesh) to Delhi
# 8   Jhansi(Uttar Pradesh) to Kanpur (Uttar Pradesh)
# 9                                Mathura to Lucknow
# 10                              Varanasi to Lucknow
# 11              Lucknow to Bareilly (Uttar Pradesh)
# 12                 Bareilly (Uttar Pradesh) to Agra
# 13                                Delhi to Haldwani
# 14             Prayagraj(Uttar Pradesh) to Azamgarh
# 15            Shahjahanpur (Uttar Pradesh) to Delhi
# 16  Jhansi(Uttar Pradesh) to Kanpur (Uttar Pradesh)
# 17                               Mathura to Lucknow
# 18                              Varanasi to Lucknow
# 19              Lucknow to Bareilly (Uttar Pradesh)
# 20                 Bareilly (Uttar Pradesh) to Agra
# 21                                Delhi to Haldwani
# 22             Prayagraj(Uttar Pradesh) to Azamgarh
# 23            Shahjahanpur (Uttar Pradesh) to Delhi
# 24  Jhansi(Uttar Pradesh) to Kanpur (Uttar Pradesh)
# 25                               Mathura to Lucknow
# 26                              Varanasi to Lucknow
# 27              Lucknow to Bareilly (Uttar Pradesh)
# 28                 Bareilly (Uttar Pradesh) to Agra
# 29                                Delhi to Haldwani
# 30             Prayagraj(Uttar Pradesh) to Azamgarh
# 31            Shahjahanpur (Uttar Pradesh) to Delhi
# 32  Jhansi(Uttar Pradesh) to Kanpur (Uttar Pradesh)
# 33                               Mathura to Lucknow
# 34                              Varanasi to Lucknow
# 35              Lucknow to Bareilly (Uttar Pradesh)
# 36                 Bareilly (Uttar Pradesh) to Agra
# 37                                Delhi to Haldwani
# 38             Prayagraj(Uttar Pradesh) to Azamgarh
# 39            Shahjahanpur (Uttar Pradesh) to Delhi
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 1   https://www.redbus.in/bus-tickets/mathura-to-l...
# 2   https://www.redbus.in/bus-tickets/varanasi-to-...
# 3   https://www.redbus.in/bus-tickets/lucknow-to-b...
# 4   https://www.redbus.in/bus-tickets/bareilly-to-...
# 5   https://www.redbus.in/bus-tickets/delhi-to-hal...
# 6   https://www.redbus.in/bus-tickets/allahabad-to...
# 7   https://www.redbus.in/bus-tickets/shahjahanpur...
# 8   https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 9   https://www.redbus.in/bus-tickets/mathura-to-l...
# 10  https://www.redbus.in/bus-tickets/varanasi-to-...
# 11  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 12  https://www.redbus.in/bus-tickets/bareilly-to-...
# 13  https://www.redbus.in/bus-tickets/delhi-to-hal...
# 14  https://www.redbus.in/bus-tickets/allahabad-to...
# 15  https://www.redbus.in/bus-tickets/shahjahanpur...
# 16  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 17  https://www.redbus.in/bus-tickets/mathura-to-l...
# 18  https://www.redbus.in/bus-tickets/varanasi-to-...
# 19  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 20  https://www.redbus.in/bus-tickets/bareilly-to-...
# 21  https://www.redbus.in/bus-tickets/delhi-to-hal...
# 22  https://www.redbus.in/bus-tickets/allahabad-to...
# 23  https://www.redbus.in/bus-tickets/shahjahanpur...
# 24  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 25  https://www.redbus.in/bus-tickets/mathura-to-l...
# 26  https://www.redbus.in/bus-tickets/varanasi-to-...
# 27  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 28  https://www.redbus.in/bus-tickets/bareilly-to-...
# 29  https://www.redbus.in/bus-tickets/delhi-to-hal...
# 30  https://www.redbus.in/bus-tickets/allahabad-to...
# 31  https://www.redbus.in/bus-tickets/shahjahanpur...
# 32  https://www.redbus.in/bus-tickets/jhansi-to-ka...
# 33  https://www.redbus.in/bus-tickets/mathura-to-l...
# 34  https://www.redbus.in/bus-tickets/varanasi-to-...
# 35  https://www.redbus.in/bus-tickets/lucknow-to-b...
# 36  https://www.redbus.in/bus-tickets/bareilly-to-...
# 37  https://www.redbus.in/bus-tickets/delhi-to-hal...
# 38  https://www.redbus.in/bus-tickets/allahabad-to...
# 39  https://www.redbus.in/bus-tickets/shahjahanpur...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_UP.csv"
df_UP.to_csv(path,index=False)

# %% [markdown]
# ## 10. West Bengal Transport Corporation (WBTC)

# %%
driver = webdriver.Chrome()
driver.get("https://www.redbus.in/online-booking/wbtc-ctc/?utm_source=rtchometile")
time.sleep(3)
driver.maximize_window()

# %%
wait = WebDriverWait(driver, 10)

def West_Bengal_Routes(path):
    WB_LINKS = []
    WB_ROUTES = []

    paths = driver.find_elements(By.XPATH,path)

    for i in range(1,5):
        try:
            for link in paths:
                href = link.get_attribute("href")
                if href:
                    WB_LINKS.append(href)
                text = link.text.strip()
                if text:
                    WB_ROUTES.append(text)

            pagination = wait.until(EC.presence_of_element_located((By.XPATH,'//*[@class="DC_117_paginationTable"]')))
            next_page = pagination.find_element(By.XPATH,'//*[@id="root"]/div/div[4]/div[10]/div[4]')
            actions = ActionChains(driver)
            actions.move_to_element(next_page).click().perform()
            
        except NoSuchElementException:
            print(f"No more pages to paginate at page {i}.")
            break

    return list(WB_LINKS) , list(WB_ROUTES)

WB_LINKS,WB_ROUTES = West_Bengal_Routes("//a[@class='route']")

# %%
df_WB = pd.DataFrame({"Route_name":WB_ROUTES,"Route_link":WB_LINKS})
df_WB
# Out:
#                                          Route_name  \
# 0                    Barasat (West Bengal) to Debra
# 1                                Habra to Midnapore
# 2   Durgapur (West Bengal) to Barasat (West Bengal)
# 3                   Habra to Durgapur (West Bengal)
# 4                                Kolkata to Purulia
# 5    Barasat (West Bengal) to Asansol (West Bengal)
# 6                                 Habra to Kolaghat
# 7                                 Kolkata to Haldia
# 8                    Barasat (West Bengal) to Debra
# 9                                Habra to Midnapore
# 10  Durgapur (West Bengal) to Barasat (West Bengal)
# 11                  Habra to Durgapur (West Bengal)
# 12                               Kolkata to Purulia
# 13   Barasat (West Bengal) to Asansol (West Bengal)
# 14                                Habra to Kolaghat
# 15                                Kolkata to Haldia
# 16                   Barasat (West Bengal) to Debra
# 17                               Habra to Midnapore
# 18  Durgapur (West Bengal) to Barasat (West Bengal)
# 19                  Habra to Durgapur (West Bengal)
# 20                               Kolkata to Purulia
# 21   Barasat (West Bengal) to Asansol (West Bengal)
# 22                                Habra to Kolaghat
# 23                                Kolkata to Haldia
# 24                   Barasat (West Bengal) to Debra
# 25                               Habra to Midnapore
# 26  Durgapur (West Bengal) to Barasat (West Bengal)
# 27                  Habra to Durgapur (West Bengal)
# 28                               Kolkata to Purulia
# 29   Barasat (West Bengal) to Asansol (West Bengal)
# 30                                Habra to Kolaghat
# 31                                Kolkata to Haldia
#
#                                            Route_link
# 0   https://www.redbus.in/bus-tickets/barasat-west...
# 1   https://www.redbus.in/bus-tickets/habra-to-mid...
# 2   https://www.redbus.in/bus-tickets/durgapur-to-...
# 3   https://www.redbus.in/bus-tickets/habra-to-dur...
# 4   https://www.redbus.in/bus-tickets/kolkata-to-p...
# 5   https://www.redbus.in/bus-tickets/barasat-west...
# 6   https://www.redbus.in/bus-tickets/habra-to-kol...
# 7   https://www.redbus.in/bus-tickets/kolkata-to-h...
# 8   https://www.redbus.in/bus-tickets/barasat-west...
# 9   https://www.redbus.in/bus-tickets/habra-to-mid...
# 10  https://www.redbus.in/bus-tickets/durgapur-to-...
# 11  https://www.redbus.in/bus-tickets/habra-to-dur...
# 12  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 13  https://www.redbus.in/bus-tickets/barasat-west...
# 14  https://www.redbus.in/bus-tickets/habra-to-kol...
# 15  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 16  https://www.redbus.in/bus-tickets/barasat-west...
# 17  https://www.redbus.in/bus-tickets/habra-to-mid...
# 18  https://www.redbus.in/bus-tickets/durgapur-to-...
# 19  https://www.redbus.in/bus-tickets/habra-to-dur...
# 20  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 21  https://www.redbus.in/bus-tickets/barasat-west...
# 22  https://www.redbus.in/bus-tickets/habra-to-kol...
# 23  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 24  https://www.redbus.in/bus-tickets/barasat-west...
# 25  https://www.redbus.in/bus-tickets/habra-to-mid...
# 26  https://www.redbus.in/bus-tickets/durgapur-to-...
# 27  https://www.redbus.in/bus-tickets/habra-to-dur...
# 28  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 29  https://www.redbus.in/bus-tickets/barasat-west...
# 30  https://www.redbus.in/bus-tickets/habra-to-kol...
# 31  https://www.redbus.in/bus-tickets/kolkata-to-h...

# %%
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_WB.csv"
df_WB.to_csv(path,index=False)

# %%
# concat all the bus link and route names in one dataframe
df=pd.concat([df_k,df_A,df_T,df_G,df_R,df_H,df_SB,df_AS,df_UP,df_WB],ignore_index=True)
df
# Out:
#                                          Route_name  \
# 0                            Bangalore to Kozhikode
# 1                            Kozhikode to Ernakulam
# 2                            Kozhikode to Bangalore
# 3                            Ernakulam to Kozhikode
# 4                               Mysore to Kozhikode
# ..                                              ...
# 278                 Habra to Durgapur (West Bengal)
# 279                              Kolkata to Purulia
# 280  Barasat (West Bengal) to Asansol (West Bengal)
# 281                               Habra to Kolaghat
# 282                               Kolkata to Haldia
#
#                                             Route_link
# 0    https://www.redbus.in/bus-tickets/bangalore-to...
# 1    https://www.redbus.in/bus-tickets/kozhikode-to...
# 2    https://www.redbus.in/bus-tickets/kozhikode-to...
# 3    https://www.redbus.in/bus-tickets/ernakulam-to...
# 4    https://www.redbus.in/bus-tickets/mysore-to-ko...
# ..                                                 ...
# 278  https://www.redbus.in/bus-tickets/habra-to-dur...
# 279  https://www.redbus.in/bus-tickets/kolkata-to-p...
# 280  https://www.redbus.in/bus-tickets/barasat-west...
# 281  https://www.redbus.in/bus-tickets/habra-to-kol...
# 282  https://www.redbus.in/bus-tickets/kolkata-to-h...
#
# [283 rows x 2 columns]

# %%
# change dataframe to csv
path=r"C:/Users/PRIYA/OneDrive/Desktop/Red_Bus_Project/States Files/df_route.csv"
df.to_csv(path,index=False)
